# %% [markdown]
# <a href="https://colab.research.google.com/github/AtSourav/L2-vs-L1-vs-CB-loss-in-deep-CNN-based-AE-on-cifar10/blob/main/AE_cifar10_CBloss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow import math
import tensorflow_datasets as tfds
from keras import losses
from keras import layers
from keras import utils
from keras import metrics
from keras import backend as K
from keras import initializers

import os
import random
import matplotlib.pyplot as plt

# %%
img_ht = 32
img_wd = 32

input_size = (img_ht,img_wd,3)
latent_dim = 200
batch_size = 128

initializer = initializers.HeNormal(seed=100)

# %%
ds = tfds.load('cifar10', split='train')
ds2= tfds.load('cifar10', split='test')

# %%
ds_to_np = list(ds.as_numpy_iterator())
ds2_to_np = list(ds2.as_numpy_iterator())

# %%
img_train = np.array([x['image'] for x in ds_to_np])
img_valid = np.array([x['image'] for x in ds2_to_np])

img_train = img_train/255
img_valid = img_valid/255

# %%
encoder_input = keras.Input(shape=input_size)

x = layers.Conv2D(64, 3, padding="valid", kernel_initializer=initializer)(encoder_input)
x = layers.ReLU()(x)

x = layers.Conv2D(64, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding="valid")(x)

x = layers.Conv2D(128, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Flatten()(x)

x = layers.Dense(3*latent_dim)(x)
x = layers.ReLU()(x)

x = layers.Dense(2*latent_dim)(x)
x = layers.ReLU()(x)


z = layers.Dense(latent_dim, name="z")(x)

encoder = keras.Model(encoder_input, z, name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 30, 30, 64)        1792
#
#  re_lu (ReLU)                (None, 30, 30, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        16448
#
#  re_lu_1 (ReLU)              (None, 29, 29, 64)        0
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 64)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 128)       32896
#
#  re_lu_2 (ReLU)              (None, 13, 13, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       65664
#
#  re_lu_3 (ReLU)              (None, 12, 12, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)       16512
#
#  re_lu_4 (ReLU)              (None, 12, 12, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 128)       65664
#
#  re_lu_5 (ReLU)              (None, 11, 11, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 10, 10, 128)       65664
#
#  re_lu_6 (ReLU)              (None, 10, 10, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 128)       16512
#
#  re_lu_7 (ReLU)              (None, 10, 10, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 9, 9, 256)         131328
#
#  re_lu_8 (ReLU)              (None, 9, 9, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 256)         262400
#
#  re_lu_9 (ReLU)              (None, 8, 8, 256)         0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 256)         65792
#
#  re_lu_10 (ReLU)             (None, 8, 8, 256)         0
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 256)         262400
#
#  re_lu_11 (ReLU)             (None, 7, 7, 256)         0
#
#  conv2d_12 (Conv2D)          (None, 6, 6, 256)         262400
#
#  re_lu_12 (ReLU)             (None, 6, 6, 256)         0
#
#  conv2d_13 (Conv2D)          (None, 6, 6, 256)         65792
#
#  re_lu_13 (ReLU)             (None, 6, 6, 256)         0
#
#  conv2d_14 (Conv2D)          (None, 5, 5, 512)         524800
#
#  re_lu_14 (ReLU)             (None, 5, 5, 512)         0
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 512)         1049088
#
#  re_lu_15 (ReLU)             (None, 4, 4, 512)         0
#
#  conv2d_16 (Conv2D)          (None, 3, 3, 512)         1049088
#
#  re_lu_16 (ReLU)             (None, 3, 3, 512)         0
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 512)         1049088
#
#  re_lu_17 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_18 (Conv2D)          (None, 1, 1, 512)         1049088
#
#  re_lu_18 (ReLU)             (None, 1, 1, 512)         0
#
#  conv2d_19 (Conv2D)          (None, 1, 1, 512)         262656
#
#  re_lu_19 (ReLU)             (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 600)               307800
#
#  re_lu_20 (ReLU)             (None, 600)               0
#
#  dense_1 (Dense)             (None, 400)               240400
#
#  re_lu_21 (ReLU)             (None, 400)               0
#
#  z (Dense)                   (None, 200)               80200
#
# =================================================================
# Total params: 6943472 (26.49 MB)
# Trainable params: 6943472 (26.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
latent_input = keras.Input(shape=(latent_dim,))

x = layers.Dense(2*latent_dim)(latent_input)
x = layers.ReLU()(x)

x = layers.Dense(3*latent_dim)(x)
x = layers.ReLU()(x)

x = layers.Dense(4*latent_dim)(x)
x = layers.ReLU()(x)

x = layers.Dense(2*2*1024)(x)
x = layers.ReLU()(x)

x = layers.Reshape((2,2,1024))(x)

x = layers.Conv2DTranspose(1024, 1, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(512, 1, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(512, 2, padding='valid', kernel_initializer=initializer)(x)
#x = layers.BatchNormalization(axis=-1)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(512, 2, padding='valid', kernel_initializer=initializer)(x)
#x = layers.BatchNormalization(axis=-1)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(256, 1, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(256, 2, padding='valid', kernel_initializer=initializer)(x)
#x = layers.BatchNormalization(axis=-1)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(256, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(256, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.UpSampling2D(size=(2, 2), data_format=None, interpolation='bilinear')(x)

x = layers.Conv2DTranspose(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.UpSampling2D(size=(2, 2), data_format=None, interpolation='bilinear')(x)

x = layers.Conv2D(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 1, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(64, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(64, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

decoder_output = layers.Conv2D(3, 1, activation='sigmoid', padding='valid', kernel_initializer=initializer)(x)

decoder = keras.Model(latent_input, decoder_output, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200)]             0
#
#  dense_2 (Dense)             (None, 400)               80400
#
#  re_lu_22 (ReLU)             (None, 400)               0
#
#  dense_3 (Dense)             (None, 600)               240600
#
#  re_lu_23 (ReLU)             (None, 600)               0
#
#  dense_4 (Dense)             (None, 800)               480800
#
#  re_lu_24 (ReLU)             (None, 800)               0
#
#  dense_5 (Dense)             (None, 4096)              3280896
#
#  re_lu_25 (ReLU)             (None, 4096)              0
#
#  reshape (Reshape)           (None, 2, 2, 1024)        0
#
#  conv2d_transpose (Conv2DTr  (None, 2, 2, 1024)        1049600
#  anspose)
#
#  re_lu_26 (ReLU)             (None, 2, 2, 1024)        0
#
#  conv2d_transpose_1 (Conv2D  (None, 2, 2, 512)         524800
#  Transpose)
#
#  re_lu_27 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_transpose_2 (Conv2D  (None, 3, 3, 512)         1049088
#  Transpose)
#
#  re_lu_28 (ReLU)             (None, 3, 3, 512)         0
#
#  conv2d_transpose_3 (Conv2D  (None, 4, 4, 512)         1049088
#  Transpose)
#
#  re_lu_29 (ReLU)             (None, 4, 4, 512)         0
#
#  conv2d_transpose_4 (Conv2D  (None, 4, 4, 256)         131328
#  Transpose)
#
#  re_lu_30 (ReLU)             (None, 4, 4, 256)         0
#
#  conv2d_transpose_5 (Conv2D  (None, 5, 5, 256)         262400
#  Transpose)
#
#  re_lu_31 (ReLU)             (None, 5, 5, 256)         0
#
#  conv2d_transpose_6 (Conv2D  (None, 6, 6, 256)         262400
#  Transpose)
#
#  re_lu_32 (ReLU)             (None, 6, 6, 256)         0
#
#  conv2d_transpose_7 (Conv2D  (None, 7, 7, 256)         262400
#  Transpose)
#
#  re_lu_33 (ReLU)             (None, 7, 7, 256)         0
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 256)       0
#  D)
#
#  conv2d_transpose_8 (Conv2D  (None, 15, 15, 128)       131200
#  Transpose)
#
#  re_lu_34 (ReLU)             (None, 15, 15, 128)       0
#
#  conv2d_transpose_9 (Conv2D  (None, 16, 16, 128)       65664
#  Transpose)
#
#  re_lu_35 (ReLU)             (None, 16, 16, 128)       0
#
#  conv2d_transpose_10 (Conv2  (None, 17, 17, 128)       65664
#  DTranspose)
#
#  re_lu_36 (ReLU)             (None, 17, 17, 128)       0
#
#  conv2d_transpose_11 (Conv2  (None, 18, 18, 128)       65664
#  DTranspose)
#
#  re_lu_37 (ReLU)             (None, 18, 18, 128)       0
#
#  up_sampling2d_1 (UpSamplin  (None, 36, 36, 128)       0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 35, 35, 128)       65664
#
#  re_lu_38 (ReLU)             (None, 35, 35, 128)       0
#
#  conv2d_21 (Conv2D)          (None, 34, 34, 128)       65664
#
#  re_lu_39 (ReLU)             (None, 34, 34, 128)       0
#
#  conv2d_22 (Conv2D)          (None, 34, 34, 128)       16512
#
#  re_lu_40 (ReLU)             (None, 34, 34, 128)       0
#
#  conv2d_23 (Conv2D)          (None, 33, 33, 64)        32832
#
#  re_lu_41 (ReLU)             (None, 33, 33, 64)        0
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 64)        16448
#
#  re_lu_42 (ReLU)             (None, 32, 32, 64)        0
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 3)         195
#
# =================================================================
# Total params: 9199307 (35.09 MB)
# Trainable params: 9199307 (35.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
decoder_out = decoder(encoder(encoder_input))
AE = keras.Model(encoder_input, decoder_out, name='AE')

AE.summary()
# Out:
# Model: "AE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  encoder (Functional)        (None, 200)               6943472
#
#  decoder (Functional)        (None, 32, 32, 3)         9199307
#
# =================================================================
# Total params: 16142779 (61.58 MB)
# Trainable params: 16142779 (61.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
l_cutoff = 0.495
u_cutoff = 0.505

def norm_CB(z):

    gate = math.logical_and(math.greater(z,l_cutoff), math.greater(u_cutoff,z))

    z = tf.clip_by_value(z, clip_value_min = K.epsilon(), clip_value_max = 1 - K.epsilon())
    z_reg = tf.where(gate, l_cutoff, z)

    norm_reg = (2*math.atanh(1 - 2*z_reg))/(1 - 2*z_reg)
    norm_taylor = 2.0 + (8.0/3.0)*math.pow(z-0.5,2) + (32.0/5.0)*math.pow(z-0.5,4)  +  (128.0/7.0)*math.pow(z-0.5,6)


    norm = tf.where(gate, norm_taylor, norm_reg)

    return norm

def CB_logloss(true, pred):
  true = layers.Flatten()(true)
  pred = layers.Flatten()(pred)
  bce = losses.binary_crossentropy(true,pred)

  corrected_loss_tensor = bce - tf.reduce_mean(math.log(norm_CB(pred)), axis=-1 )


  return tf.reduce_mean(corrected_loss_tensor)

# %%
K.clear_session()

# %%
callback = keras.callbacks.EarlyStopping(monitor='loss', patience=3, verbose=1, start_from_epoch=10, restore_best_weights=True)
optim = keras.optimizers.Adam(learning_rate = 0.0001)
AE.compile(optimizer=optim,loss=CB_logloss)
history = AE.fit(img_train, img_train, batch_size=batch_size, validation_data=(img_valid, img_valid), epochs=100, callbacks=[callback])
# Out:
# Epoch 1/100
# 391/391 [==============================] - 39s 42ms/step - loss: -0.1557 - val_loss: -0.2449
# Epoch 2/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.2634 - val_loss: -0.2804
# Epoch 3/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.2881 - val_loss: -0.2949
# Epoch 4/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3067 - val_loss: -0.3126
# Epoch 5/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3189 - val_loss: -0.3197
# Epoch 6/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3261 - val_loss: -0.3303
# Epoch 7/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.3355 - val_loss: -0.3396
# Epoch 8/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3449 - val_loss: -0.3400
# Epoch 9/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3518 - val_loss: -0.3493
# Epoch 10/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3562 - val_loss: -0.3556
# Epoch 11/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.3634 - val_loss: -0.3602
# Epoch 12/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3681 - val_loss: -0.3584
# Epoch 13/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3713 - val_loss: -0.3664
# Epoch 14/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3748 - val_loss: -0.3677
# Epoch 15/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3766 - val_loss: -0.3689
# Epoch 16/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.3785 - val_loss: -0.3707
# Epoch 17/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3803 - val_loss: -0.3689
# Epoch 18/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3819 - val_loss: -0.3762
# Epoch 19/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3834 - val_loss: -0.3772
# Epoch 20/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3869 - val_loss: -0.3804
# Epoch 21/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.3891 - val_loss: -0.3726
# Epoch 22/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3905 - val_loss: -0.3820
# Epoch 23/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3927 - val_loss: -0.3857
# Epoch 24/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3943 - val_loss: -0.3860
# Epoch 25/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3969 - val_loss: -0.3874
# Epoch 26/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3981 - val_loss: -0.3889
# Epoch 27/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3985 - val_loss: -0.3894
# Epoch 28/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.3996 - val_loss: -0.3906
# Epoch 29/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4015 - val_loss: -0.3903
# Epoch 30/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4022 - val_loss: -0.3898
# Epoch 31/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4040 - val_loss: -0.3910
# Epoch 32/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4036 - val_loss: -0.3946
# Epoch 33/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4051 - val_loss: -0.3944
# Epoch 34/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4057 - val_loss: -0.3952
# Epoch 35/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4068 - val_loss: -0.3891
# Epoch 36/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4079 - val_loss: -0.3929
# Epoch 37/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4092 - val_loss: -0.3973
# Epoch 38/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4102 - val_loss: -0.3940
# Epoch 39/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4105 - val_loss: -0.3984
# Epoch 40/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4119 - val_loss: -0.3968
# Epoch 41/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4117 - val_loss: -0.3981
# Epoch 42/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4144 - val_loss: -0.3971
# Epoch 43/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4143 - val_loss: -0.3996
# Epoch 44/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4162 - val_loss: -0.3995
# Epoch 45/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4158 - val_loss: -0.4006
# Epoch 46/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4177 - val_loss: -0.4017
# Epoch 47/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4174 - val_loss: -0.4019
# Epoch 48/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4190 - val_loss: -0.4012
# Epoch 49/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4187 - val_loss: -0.4030
# Epoch 50/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4199 - val_loss: -0.4031
# Epoch 51/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4198 - val_loss: -0.4023
# Epoch 52/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4223 - val_loss: -0.4027
# Epoch 53/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4227 - val_loss: -0.4043
# Epoch 54/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4225 - val_loss: -0.4015
# Epoch 55/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4232 - val_loss: -0.4047
# Epoch 56/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4247 - val_loss: -0.4034
# Epoch 57/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4253 - val_loss: -0.4028
# Epoch 58/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4248 - val_loss: -0.4045
# Epoch 59/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4260 - val_loss: -0.4029
# Epoch 60/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4275 - val_loss: -0.4048
# Epoch 61/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4266 - val_loss: -0.4038
# Epoch 62/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4278 - val_loss: -0.4040
# Epoch 63/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4286 - val_loss: -0.4057
# Epoch 64/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4295 - val_loss: -0.4060
# Epoch 65/100
# 391/391 [==============================] - 10s 26ms/step - loss: -0.4286 - val_loss: -0.4048
# Epoch 66/100
# 391/391 [==============================] - 10s 26ms/step - loss: -0.4305 - val_loss: -0.4040
# Epoch 67/100
# 391/391 [==============================] - 10s 26ms/step - loss: -0.4307 - val_loss: -0.4057
# Epoch 68/100
# 391/391 [==============================] - 10s 26ms/step - loss: -0.4306 - val_loss: -0.4061
# Epoch 69/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4316 - val_loss: -0.4036
# Epoch 70/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4326 - val_loss: -0.4054
# Epoch 71/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4327 - val_loss: -0.4048
# Epoch 72/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4330 - val_loss: -0.4052
# Epoch 73/100
# 391/391 [==============================] - 11s 27ms/step - loss: -0.4345 - val_loss: -0.4064
# Epoch 74/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4346 - val_loss: -0.4039
# Epoch 75/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4349 - val_loss: -0.4023
# Epoch 76/100
# 391/391 [==============================] - 11s 27ms/step - loss: -0.4353 - val_loss: -0.4062
# Epoch 77/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4358 - val_loss: -0.4046
# Epoch 78/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4368 - val_loss: -0.4065
# Epoch 79/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4369 - val_loss: -0.4046
# Epoch 80/100
# 391/391 [==============================] - 11s 27ms/step - loss: -0.4377 - val_loss: -0.4049
# Epoch 81/100
# 391/391 [==============================] - 10s 27ms/step - loss: -0.4376 - val_loss: -0.4046
# Epoch 82/100
# 391/391 [==============================] - 11s 27ms/step - loss: -0.4381 - val_loss: -0.4056
# Epoch 83/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4380 - val_loss: -0.4061
# Epoch 84/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4397 - val_loss: -0.4032
# Epoch 85/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4388 - val_loss: -0.4003
# Epoch 86/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4405 - val_loss: -0.4056
# Epoch 87/100
# 391/391 [==============================] - 11s 27ms/step - loss: -0.4407 - val_loss: -0.4058
# Epoch 88/100
# 391/391 [==============================] - 11s 27ms/step - loss: -0.4408 - val_loss: -0.4063
# Epoch 89/100
# 391/391 [==============================] - 11s 27ms/step - loss: -0.4417 - val_loss: -0.3990
# Epoch 90/100
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4407 - val_loss: -0.4022
# Epoch 91/100
# 391/391 [==============================] - 12s 30ms/step - loss: -0.4426 - val_loss: -0.4033
# Epoch 92/100
# 391/391 [==============================] - 12s 30ms/step - loss: -0.4428 - val_loss: -0.4061
# Epoch 93/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4428 - val_loss: -0.4060
# Epoch 94/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4437 - val_loss: -0.4027
# Epoch 95/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4437 - val_loss: -0.4051
# Epoch 96/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4441 - val_loss: -0.4060
# Epoch 97/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4434 - val_loss: -0.4062
# Epoch 98/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4455 - val_loss: -0.4073
# Epoch 99/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4451 - val_loss: -0.4040
# Epoch 100/100
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4458 - val_loss: -0.4034

# %%
callback = keras.callbacks.EarlyStopping(monitor='loss', patience=3, verbose=1, start_from_epoch=1, restore_best_weights=True)
optim = keras.optimizers.Adam(learning_rate = 0.00005)
AE.compile(optimizer=optim,loss=CB_logloss)
history2 = AE.fit(img_train, img_train, batch_size=batch_size, validation_data=(img_valid, img_valid), epochs=60, callbacks=[callback])
# Out:
# Epoch 1/60
# 391/391 [==============================] - 25s 31ms/step - loss: -0.4488 - val_loss: -0.4047
# Epoch 2/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4508 - val_loss: -0.4056
# Epoch 3/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4512 - val_loss: -0.4039
# Epoch 4/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4516 - val_loss: -0.4043
# Epoch 5/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4520 - val_loss: -0.4054
# Epoch 6/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4522 - val_loss: -0.4044
# Epoch 7/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4526 - val_loss: -0.4040
# Epoch 8/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4529 - val_loss: -0.4043
# Epoch 9/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4532 - val_loss: -0.4044
# Epoch 10/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4535 - val_loss: -0.4033
# Epoch 11/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4539 - val_loss: -0.4040
# Epoch 12/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4542 - val_loss: -0.4032
# Epoch 13/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4544 - val_loss: -0.4017
# Epoch 14/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4546 - val_loss: -0.4037
# Epoch 15/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4549 - val_loss: -0.4022
# Epoch 16/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4553 - val_loss: -0.4040
# Epoch 17/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4553 - val_loss: -0.4013
# Epoch 18/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4557 - val_loss: -0.4017
# Epoch 19/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4560 - val_loss: -0.4019
# Epoch 20/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4561 - val_loss: -0.4010
# Epoch 21/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4564 - val_loss: -0.4015
# Epoch 22/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4566 - val_loss: -0.4021
# Epoch 23/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4569 - val_loss: -0.4000
# Epoch 24/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4572 - val_loss: -0.4005
# Epoch 25/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4572 - val_loss: -0.4004
# Epoch 26/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4577 - val_loss: -0.4000
# Epoch 27/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4578 - val_loss: -0.4014
# Epoch 28/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4581 - val_loss: -0.4012
# Epoch 29/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4583 - val_loss: -0.3994
# Epoch 30/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4583 - val_loss: -0.3986
# Epoch 31/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4587 - val_loss: -0.4014
# Epoch 32/60
# 391/391 [==============================] - 12s 30ms/step - loss: -0.4588 - val_loss: -0.3990
# Epoch 33/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4590 - val_loss: -0.3986
# Epoch 34/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4592 - val_loss: -0.4001
# Epoch 35/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4596 - val_loss: -0.3990
# Epoch 36/60
# 391/391 [==============================] - 12s 30ms/step - loss: -0.4597 - val_loss: -0.3992
# Epoch 37/60
# 391/391 [==============================] - 12s 30ms/step - loss: -0.4597 - val_loss: -0.3979
# Epoch 38/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4599 - val_loss: -0.3980
# Epoch 39/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4602 - val_loss: -0.3956
# Epoch 40/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4604 - val_loss: -0.4003
# Epoch 41/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4605 - val_loss: -0.3981
# Epoch 42/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4608 - val_loss: -0.3995
# Epoch 43/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4609 - val_loss: -0.3960
# Epoch 44/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4611 - val_loss: -0.3974
# Epoch 45/60
# 391/391 [==============================] - 12s 30ms/step - loss: -0.4613 - val_loss: -0.3979
# Epoch 46/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4615 - val_loss: -0.3985
# Epoch 47/60
# 391/391 [==============================] - 12s 29ms/step - loss: -0.4615 - val_loss: -0.3958
# Epoch 48/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4618 - val_loss: -0.3962
# Epoch 49/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4617 - val_loss: -0.3973
# Epoch 50/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4619 - val_loss: -0.3964
# Epoch 51/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4622 - val_loss: -0.3963
# Epoch 52/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4624 - val_loss: -0.3967
# Epoch 53/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4626 - val_loss: -0.3964
# Epoch 54/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4627 - val_loss: -0.3958
# Epoch 55/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4629 - val_loss: -0.3963
# Epoch 56/60
# 391/391 [==============================] - 11s 29ms/step - loss: -0.4631 - val_loss: -0.3954
# Epoch 57/60
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4632 - val_loss: -0.3962
# Epoch 58/60
# 391/391 [==============================] - 11s 27ms/step - loss: -0.4630 - val_loss: -0.3971
# Epoch 59/60
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4636 - val_loss: -0.3965
# Epoch 60/60
# 391/391 [==============================] - 11s 28ms/step - loss: -0.4636 - val_loss: -0.3945

# %% [markdown]
# We have overtrained already.

# %%
plt.plot(history.history['loss']+history2.history['loss'])
plt.plot(history.history['val_loss']+history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
def plot_reconstruction(set, name,seed_val, epochs):     #name should be either 'training' or 'validation'
  np.random.seed(seed_val)

  tg_indices = np.random.randint(0,set.shape[0],size = 16)
  img_sample = tf.convert_to_tensor(np.array(set)[tg_indices])
  z_sample = encoder(img_sample)
  img_recon = decoder(z_sample)

  recon = plt.figure(figsize=(9,4))
  recon.suptitle('Reconstructed images (right) from the ' + name + '-set after ' + str(epochs) + ' epochs: latent_dim =' + str(latent_dim), fontweight= 'bold', y=0.93)

  recon.tight_layout()

  for i in range(36):
    recon.add_subplot(4,9,i+1)
    j = int(np.floor(i/9))
    if (i%9) <4:
      img = set[tg_indices[j*4 + (i%9)]]
      plt.imshow(img)
      plt.axis('off')
    elif (i%9)==4:
      img = np.ones((32,32,3))
      plt.imshow(img)
      plt.axis('off')
    else:
      img = img_recon[j*4 + (i%9) - 5]
      plt.imshow(img)
      plt.axis('off')

# %%
plot_reconstruction(img_train, 'training',123,160)

# %%
plot_reconstruction(img_valid,'validation',123,160)

# %% [markdown]
# We waited for the network (with the same architecture that we optimised with mse loss) to overtrain w.r.t.the continuous Bernoulli log loss and then the results are above. The reconstructed images have bright colours and sharp contrast as expected.
