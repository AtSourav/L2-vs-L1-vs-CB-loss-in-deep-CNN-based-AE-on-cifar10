# %% [markdown]
# <a href="https://colab.research.google.com/github/AtSourav/L2-vs-L1-vs-CB-loss-in-deep-CNN-based-AE-on-cifar10/blob/main/AE_cifar10_L1_HeNormal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow import math
import tensorflow_datasets as tfds
from keras import losses
from keras import layers
from keras import utils
from keras import metrics
from keras import backend as K
from keras import initializers

import os
import random
import matplotlib.pyplot as plt

# %%
img_ht = 32
img_wd = 32

input_size = (img_ht,img_wd,3)
latent_dim = 200
batch_size = 128

initializer = initializers.HeNormal(seed=100)

# %% [markdown]
# # **Loading the dataset**

# %%
ds = tfds.load('cifar10', split='train')
ds2= tfds.load('cifar10', split='test')

# %%
ds_to_np = list(ds.as_numpy_iterator())
ds2_to_np = list(ds2.as_numpy_iterator())

# %%
img_train = np.array([x['image'] for x in ds_to_np])
img_valid = np.array([x['image'] for x in ds2_to_np])

img_train = img_train/255
img_valid = img_valid/255

# %% [markdown]
# # **Building the model**

# %%
encoder_input = keras.Input(shape=input_size)

x = layers.Conv2D(64, 3, padding="valid", kernel_initializer=initializer)(encoder_input)
x = layers.ReLU()(x)

x = layers.Conv2D(64, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding="valid")(x)

x = layers.Conv2D(128, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(256, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 2, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(512, 1, padding="valid", kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Flatten()(x)

x = layers.Dense(3*latent_dim)(x)
x = layers.ReLU()(x)

x = layers.Dense(2*latent_dim)(x)
x = layers.ReLU()(x)


z = layers.Dense(latent_dim, name="z")(x)

encoder = keras.Model(encoder_input, z, name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 30, 30, 64)        1792
#
#  re_lu (ReLU)                (None, 30, 30, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        16448
#
#  re_lu_1 (ReLU)              (None, 29, 29, 64)        0
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 64)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 128)       32896
#
#  re_lu_2 (ReLU)              (None, 13, 13, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       65664
#
#  re_lu_3 (ReLU)              (None, 12, 12, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)       16512
#
#  re_lu_4 (ReLU)              (None, 12, 12, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 128)       65664
#
#  re_lu_5 (ReLU)              (None, 11, 11, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 10, 10, 128)       65664
#
#  re_lu_6 (ReLU)              (None, 10, 10, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 128)       16512
#
#  re_lu_7 (ReLU)              (None, 10, 10, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 9, 9, 256)         131328
#
#  re_lu_8 (ReLU)              (None, 9, 9, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 256)         262400
#
#  re_lu_9 (ReLU)              (None, 8, 8, 256)         0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 256)         65792
#
#  re_lu_10 (ReLU)             (None, 8, 8, 256)         0
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 256)         262400
#
#  re_lu_11 (ReLU)             (None, 7, 7, 256)         0
#
#  conv2d_12 (Conv2D)          (None, 6, 6, 256)         262400
#
#  re_lu_12 (ReLU)             (None, 6, 6, 256)         0
#
#  conv2d_13 (Conv2D)          (None, 6, 6, 256)         65792
#
#  re_lu_13 (ReLU)             (None, 6, 6, 256)         0
#
#  conv2d_14 (Conv2D)          (None, 5, 5, 512)         524800
#
#  re_lu_14 (ReLU)             (None, 5, 5, 512)         0
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 512)         1049088
#
#  re_lu_15 (ReLU)             (None, 4, 4, 512)         0
#
#  conv2d_16 (Conv2D)          (None, 3, 3, 512)         1049088
#
#  re_lu_16 (ReLU)             (None, 3, 3, 512)         0
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 512)         1049088
#
#  re_lu_17 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_18 (Conv2D)          (None, 1, 1, 512)         1049088
#
#  re_lu_18 (ReLU)             (None, 1, 1, 512)         0
#
#  conv2d_19 (Conv2D)          (None, 1, 1, 512)         262656
#
#  re_lu_19 (ReLU)             (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 600)               307800
#
#  re_lu_20 (ReLU)             (None, 600)               0
#
#  dense_1 (Dense)             (None, 400)               240400
#
#  re_lu_21 (ReLU)             (None, 400)               0
#
#  z (Dense)                   (None, 200)               80200
#
# =================================================================
# Total params: 6943472 (26.49 MB)
# Trainable params: 6943472 (26.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
latent_input = keras.Input(shape=(latent_dim,))

x = layers.Dense(2*latent_dim)(latent_input)
x = layers.ReLU()(x)

x = layers.Dense(3*latent_dim)(x)
x = layers.ReLU()(x)

x = layers.Dense(4*latent_dim)(x)
x = layers.ReLU()(x)

x = layers.Dense(2*2*1024)(x)
x = layers.ReLU()(x)

x = layers.Reshape((2,2,1024))(x)

x = layers.Conv2DTranspose(1024, 1, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(512, 1, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(512, 2, padding='valid', kernel_initializer=initializer)(x)
#x = layers.BatchNormalization(axis=-1)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(512, 2, padding='valid', kernel_initializer=initializer)(x)
#x = layers.BatchNormalization(axis=-1)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(256, 1, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(256, 2, padding='valid', kernel_initializer=initializer)(x)
#x = layers.BatchNormalization(axis=-1)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(256, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(256, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.UpSampling2D(size=(2, 2), data_format=None, interpolation='bilinear')(x)

x = layers.Conv2DTranspose(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2DTranspose(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.UpSampling2D(size=(2, 2), data_format=None, interpolation='bilinear')(x)

x = layers.Conv2D(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(128, 1, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(64, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

x = layers.Conv2D(64, 2, padding='valid', kernel_initializer=initializer)(x)
x = layers.ReLU()(x)

decoder_output = layers.Conv2D(3, 1, activation='sigmoid', padding='valid', kernel_initializer=initializer)(x)

decoder = keras.Model(latent_input, decoder_output, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200)]             0
#
#  dense_2 (Dense)             (None, 400)               80400
#
#  re_lu_22 (ReLU)             (None, 400)               0
#
#  dense_3 (Dense)             (None, 600)               240600
#
#  re_lu_23 (ReLU)             (None, 600)               0
#
#  dense_4 (Dense)             (None, 800)               480800
#
#  re_lu_24 (ReLU)             (None, 800)               0
#
#  dense_5 (Dense)             (None, 4096)              3280896
#
#  re_lu_25 (ReLU)             (None, 4096)              0
#
#  reshape (Reshape)           (None, 2, 2, 1024)        0
#
#  conv2d_transpose (Conv2DTr  (None, 2, 2, 1024)        1049600
#  anspose)
#
#  re_lu_26 (ReLU)             (None, 2, 2, 1024)        0
#
#  conv2d_transpose_1 (Conv2D  (None, 2, 2, 512)         524800
#  Transpose)
#
#  re_lu_27 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_transpose_2 (Conv2D  (None, 3, 3, 512)         1049088
#  Transpose)
#
#  re_lu_28 (ReLU)             (None, 3, 3, 512)         0
#
#  conv2d_transpose_3 (Conv2D  (None, 4, 4, 512)         1049088
#  Transpose)
#
#  re_lu_29 (ReLU)             (None, 4, 4, 512)         0
#
#  conv2d_transpose_4 (Conv2D  (None, 4, 4, 256)         131328
#  Transpose)
#
#  re_lu_30 (ReLU)             (None, 4, 4, 256)         0
#
#  conv2d_transpose_5 (Conv2D  (None, 5, 5, 256)         262400
#  Transpose)
#
#  re_lu_31 (ReLU)             (None, 5, 5, 256)         0
#
#  conv2d_transpose_6 (Conv2D  (None, 6, 6, 256)         262400
#  Transpose)
#
#  re_lu_32 (ReLU)             (None, 6, 6, 256)         0
#
#  conv2d_transpose_7 (Conv2D  (None, 7, 7, 256)         262400
#  Transpose)
#
#  re_lu_33 (ReLU)             (None, 7, 7, 256)         0
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 256)       0
#  D)
#
#  conv2d_transpose_8 (Conv2D  (None, 15, 15, 128)       131200
#  Transpose)
#
#  re_lu_34 (ReLU)             (None, 15, 15, 128)       0
#
#  conv2d_transpose_9 (Conv2D  (None, 16, 16, 128)       65664
#  Transpose)
#
#  re_lu_35 (ReLU)             (None, 16, 16, 128)       0
#
#  conv2d_transpose_10 (Conv2  (None, 17, 17, 128)       65664
#  DTranspose)
#
#  re_lu_36 (ReLU)             (None, 17, 17, 128)       0
#
#  conv2d_transpose_11 (Conv2  (None, 18, 18, 128)       65664
#  DTranspose)
#
#  re_lu_37 (ReLU)             (None, 18, 18, 128)       0
#
#  up_sampling2d_1 (UpSamplin  (None, 36, 36, 128)       0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 35, 35, 128)       65664
#
#  re_lu_38 (ReLU)             (None, 35, 35, 128)       0
#
#  conv2d_21 (Conv2D)          (None, 34, 34, 128)       65664
#
#  re_lu_39 (ReLU)             (None, 34, 34, 128)       0
#
#  conv2d_22 (Conv2D)          (None, 34, 34, 128)       16512
#
#  re_lu_40 (ReLU)             (None, 34, 34, 128)       0
#
#  conv2d_23 (Conv2D)          (None, 33, 33, 64)        32832
#
#  re_lu_41 (ReLU)             (None, 33, 33, 64)        0
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 64)        16448
#
#  re_lu_42 (ReLU)             (None, 32, 32, 64)        0
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 3)         195
#
# =================================================================
# Total params: 9199307 (35.09 MB)
# Trainable params: 9199307 (35.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
decoder_out = decoder(encoder(encoder_input))
AE = keras.Model(encoder_input, decoder_out, name='AE')

AE.summary()
# Out:
# Model: "AE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  encoder (Functional)        (None, 200)               6943472
#
#  decoder (Functional)        (None, 32, 32, 3)         9199307
#
# =================================================================
# Total params: 16142779 (61.58 MB)
# Trainable params: 16142779 (61.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # **Defining the Continuous Bernoulli loss function**

# %%
l_cutoff = 0.495
u_cutoff = 0.505

def norm_CB(z):

    gate = math.logical_and(math.greater(z,l_cutoff), math.greater(u_cutoff,z))

    z_reg = tf.where(gate, l_cutoff, z)

    norm_reg = (2*math.atanh(1 - 2*z_reg))/(1 - 2*z_reg)
    norm_taylor = 2.0 + (8.0/3.0)*math.pow(z-0.5,2) + (32.0/5.0)*math.pow(z-0.5,4)  +  (128.0/7.0)*math.pow(z-0.5,6)


    norm = tf.where(gate, norm_taylor, norm_reg)

    return norm

def CB_logloss(true, pred):
  true = layers.Flatten()(true)
  pred = layers.Flatten()(pred)
  bce = losses.binary_crossentropy(true,pred)

  corrected_loss_tensor = bce + tf.reduce_mean(math.log(norm_CB(pred)), axis=-1 )


  return tf.reduce_mean(corrected_loss_tensor)

# %% [markdown]
# # **Training**

# %%
K.clear_session()

# %%
optim = keras.optimizers.Adam(learning_rate = 0.0001)
AE.compile(optimizer=optim,loss='mae', metrics=['mse',CB_logloss])
history = AE.fit(img_train, img_train, batch_size=batch_size, validation_data=(img_valid, img_valid), epochs=15, steps_per_epoch=None)
# Out:
# Epoch 1/15
# 391/391 [==============================] - 36s 61ms/step - loss: 0.1508 - mse: 0.0377 - CB_logloss: 1.3827 - val_loss: 0.1263 - val_mse: 0.0276 - val_CB_logloss: 1.3833
# Epoch 2/15
# 391/391 [==============================] - 22s 58ms/step - loss: 0.1203 - mse: 0.0255 - CB_logloss: 1.3825 - val_loss: 0.1141 - val_mse: 0.0233 - val_CB_logloss: 1.3834
# Epoch 3/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.1112 - mse: 0.0222 - CB_logloss: 1.3824 - val_loss: 0.1072 - val_mse: 0.0208 - val_CB_logloss: 1.3743
# Epoch 4/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.1040 - mse: 0.0200 - CB_logloss: 1.3821 - val_loss: 0.1007 - val_mse: 0.0190 - val_CB_logloss: 1.3828
# Epoch 5/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.1006 - mse: 0.0189 - CB_logloss: 1.3829 - val_loss: 0.1004 - val_mse: 0.0189 - val_CB_logloss: 1.3814
# Epoch 6/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0976 - mse: 0.0180 - CB_logloss: 1.3831 - val_loss: 0.0972 - val_mse: 0.0177 - val_CB_logloss: 1.3757
# Epoch 7/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0949 - mse: 0.0171 - CB_logloss: 1.3832 - val_loss: 0.0957 - val_mse: 0.0173 - val_CB_logloss: 1.3872
# Epoch 8/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0924 - mse: 0.0164 - CB_logloss: 1.3833 - val_loss: 0.0912 - val_mse: 0.0160 - val_CB_logloss: 1.3852
# Epoch 9/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0906 - mse: 0.0158 - CB_logloss: inf - val_loss: 0.0915 - val_mse: 0.0161 - val_CB_logloss: 1.3933
# Epoch 10/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0896 - mse: 0.0155 - CB_logloss: inf - val_loss: 0.0887 - val_mse: 0.0153 - val_CB_logloss: 1.3801
# Epoch 11/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0879 - mse: 0.0151 - CB_logloss: inf - val_loss: 0.0909 - val_mse: 0.0158 - val_CB_logloss: 1.3909
# Epoch 12/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0873 - mse: 0.0149 - CB_logloss: inf - val_loss: 0.0879 - val_mse: 0.0151 - val_CB_logloss: 1.3933
# Epoch 13/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0867 - mse: 0.0147 - CB_logloss: inf - val_loss: 0.0873 - val_mse: 0.0150 - val_CB_logloss: 1.3861
# Epoch 14/15
# 391/391 [==============================] - 23s 59ms/step - loss: 0.0854 - mse: 0.0144 - CB_logloss: inf - val_loss: 0.0879 - val_mse: 0.0149 - val_CB_logloss: 1.3799
# Epoch 15/15
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0850 - mse: 0.0143 - CB_logloss: inf - val_loss: 0.0851 - val_mse: 0.0142 - val_CB_logloss: 1.3792

# %%
optim = keras.optimizers.Adam(learning_rate = 0.00005)
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=1, start_from_epoch=10, restore_best_weights=True)
AE.compile(optimizer=optim,loss='mae',metrics=['mse',CB_logloss])
history2 = AE.fit(img_train, img_train, batch_size=batch_size, validation_data=(img_valid, img_valid), epochs=120, callbacks=[callback], steps_per_epoch=None)
# Out:
# Epoch 1/120
# 391/391 [==============================] - 35s 62ms/step - loss: 0.0836 - mse: 0.0140 - CB_logloss: inf - val_loss: 0.0834 - val_mse: 0.0138 - val_CB_logloss: 1.3804
# Epoch 2/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0817 - mse: 0.0134 - CB_logloss: inf - val_loss: 0.0836 - val_mse: 0.0139 - val_CB_logloss: inf
# Epoch 3/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0811 - mse: 0.0132 - CB_logloss: inf - val_loss: 0.0821 - val_mse: 0.0136 - val_CB_logloss: inf
# Epoch 4/120
# 391/391 [==============================] - 22s 58ms/step - loss: 0.0802 - mse: 0.0130 - CB_logloss: inf - val_loss: 0.0819 - val_mse: 0.0134 - val_CB_logloss: inf
# Epoch 5/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0794 - mse: 0.0128 - CB_logloss: inf - val_loss: 0.0808 - val_mse: 0.0130 - val_CB_logloss: inf
# Epoch 6/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0790 - mse: 0.0126 - CB_logloss: inf - val_loss: 0.0807 - val_mse: 0.0130 - val_CB_logloss: inf
# Epoch 7/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0783 - mse: 0.0124 - CB_logloss: inf - val_loss: 0.0798 - val_mse: 0.0127 - val_CB_logloss: inf
# Epoch 8/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0779 - mse: 0.0123 - CB_logloss: inf - val_loss: 0.0799 - val_mse: 0.0128 - val_CB_logloss: inf
# Epoch 9/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0776 - mse: 0.0122 - CB_logloss: inf - val_loss: 0.0793 - val_mse: 0.0126 - val_CB_logloss: inf
# Epoch 10/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0771 - mse: 0.0121 - CB_logloss: inf - val_loss: 0.0792 - val_mse: 0.0126 - val_CB_logloss: inf
# Epoch 11/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0769 - mse: 0.0121 - CB_logloss: inf - val_loss: 0.0794 - val_mse: 0.0126 - val_CB_logloss: inf
# Epoch 12/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0765 - mse: 0.0119 - CB_logloss: inf - val_loss: 0.0784 - val_mse: 0.0124 - val_CB_logloss: inf
# Epoch 13/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0762 - mse: 0.0119 - CB_logloss: inf - val_loss: 0.0785 - val_mse: 0.0123 - val_CB_logloss: inf
# Epoch 14/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0759 - mse: 0.0118 - CB_logloss: inf - val_loss: 0.0782 - val_mse: 0.0124 - val_CB_logloss: inf
# Epoch 15/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0756 - mse: 0.0117 - CB_logloss: inf - val_loss: 0.0779 - val_mse: 0.0122 - val_CB_logloss: inf
# Epoch 16/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0753 - mse: 0.0116 - CB_logloss: inf - val_loss: 0.0776 - val_mse: 0.0122 - val_CB_logloss: inf
# Epoch 17/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0749 - mse: 0.0115 - CB_logloss: inf - val_loss: 0.0774 - val_mse: 0.0121 - val_CB_logloss: inf
# Epoch 18/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0746 - mse: 0.0115 - CB_logloss: inf - val_loss: 0.0772 - val_mse: 0.0121 - val_CB_logloss: inf
# Epoch 19/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0742 - mse: 0.0114 - CB_logloss: inf - val_loss: 0.0772 - val_mse: 0.0121 - val_CB_logloss: inf
# Epoch 20/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0739 - mse: 0.0113 - CB_logloss: inf - val_loss: 0.0765 - val_mse: 0.0119 - val_CB_logloss: inf
# Epoch 21/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0735 - mse: 0.0112 - CB_logloss: inf - val_loss: 0.0763 - val_mse: 0.0118 - val_CB_logloss: inf
# Epoch 22/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0731 - mse: 0.0111 - CB_logloss: inf - val_loss: 0.0761 - val_mse: 0.0118 - val_CB_logloss: inf
# Epoch 23/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0728 - mse: 0.0110 - CB_logloss: inf - val_loss: 0.0760 - val_mse: 0.0117 - val_CB_logloss: inf
# Epoch 24/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0725 - mse: 0.0109 - CB_logloss: inf - val_loss: 0.0751 - val_mse: 0.0116 - val_CB_logloss: inf
# Epoch 25/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0721 - mse: 0.0108 - CB_logloss: inf - val_loss: 0.0753 - val_mse: 0.0116 - val_CB_logloss: inf
# Epoch 26/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0718 - mse: 0.0107 - CB_logloss: inf - val_loss: 0.0747 - val_mse: 0.0114 - val_CB_logloss: inf
# Epoch 27/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0714 - mse: 0.0106 - CB_logloss: inf - val_loss: 0.0746 - val_mse: 0.0114 - val_CB_logloss: inf
# Epoch 28/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0712 - mse: 0.0106 - CB_logloss: inf - val_loss: 0.0745 - val_mse: 0.0114 - val_CB_logloss: inf
# Epoch 29/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0710 - mse: 0.0105 - CB_logloss: inf - val_loss: 0.0740 - val_mse: 0.0112 - val_CB_logloss: inf
# Epoch 30/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0706 - mse: 0.0104 - CB_logloss: inf - val_loss: 0.0741 - val_mse: 0.0113 - val_CB_logloss: inf
# Epoch 31/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0704 - mse: 0.0104 - CB_logloss: inf - val_loss: 0.0749 - val_mse: 0.0114 - val_CB_logloss: inf
# Epoch 32/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0701 - mse: 0.0103 - CB_logloss: inf - val_loss: 0.0740 - val_mse: 0.0112 - val_CB_logloss: inf
# Epoch 33/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0700 - mse: 0.0103 - CB_logloss: inf - val_loss: 0.0741 - val_mse: 0.0112 - val_CB_logloss: inf
# Epoch 34/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0696 - mse: 0.0102 - CB_logloss: inf - val_loss: 0.0736 - val_mse: 0.0111 - val_CB_logloss: inf
# Epoch 35/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0694 - mse: 0.0101 - CB_logloss: inf - val_loss: 0.0729 - val_mse: 0.0110 - val_CB_logloss: inf
# Epoch 36/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0691 - mse: 0.0101 - CB_logloss: inf - val_loss: 0.0726 - val_mse: 0.0109 - val_CB_logloss: inf
# Epoch 37/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0689 - mse: 0.0100 - CB_logloss: inf - val_loss: 0.0731 - val_mse: 0.0110 - val_CB_logloss: inf
# Epoch 38/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0687 - mse: 0.0100 - CB_logloss: inf - val_loss: 0.0724 - val_mse: 0.0109 - val_CB_logloss: inf
# Epoch 39/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0684 - mse: 0.0099 - CB_logloss: inf - val_loss: 0.0724 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 40/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0682 - mse: 0.0099 - CB_logloss: inf - val_loss: 0.0727 - val_mse: 0.0109 - val_CB_logloss: inf
# Epoch 41/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0680 - mse: 0.0098 - CB_logloss: inf - val_loss: 0.0723 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 42/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0679 - mse: 0.0098 - CB_logloss: inf - val_loss: 0.0719 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 43/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0677 - mse: 0.0097 - CB_logloss: inf - val_loss: 0.0722 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 44/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0675 - mse: 0.0097 - CB_logloss: inf - val_loss: 0.0722 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 45/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0672 - mse: 0.0096 - CB_logloss: inf - val_loss: 0.0722 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 46/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0671 - mse: 0.0096 - CB_logloss: inf - val_loss: 0.0716 - val_mse: 0.0107 - val_CB_logloss: inf
# Epoch 47/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0669 - mse: 0.0095 - CB_logloss: inf - val_loss: 0.0726 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 48/120
# 391/391 [==============================] - 22s 58ms/step - loss: 0.0667 - mse: 0.0095 - CB_logloss: inf - val_loss: 0.0715 - val_mse: 0.0106 - val_CB_logloss: inf
# Epoch 49/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0664 - mse: 0.0094 - CB_logloss: inf - val_loss: 0.0723 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 50/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0663 - mse: 0.0094 - CB_logloss: inf - val_loss: 0.0718 - val_mse: 0.0107 - val_CB_logloss: inf
# Epoch 51/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0663 - mse: 0.0094 - CB_logloss: inf - val_loss: 0.0715 - val_mse: 0.0107 - val_CB_logloss: inf
# Epoch 52/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0660 - mse: 0.0093 - CB_logloss: inf - val_loss: 0.0721 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 53/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0658 - mse: 0.0093 - CB_logloss: inf - val_loss: 0.0712 - val_mse: 0.0106 - val_CB_logloss: inf
# Epoch 54/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0657 - mse: 0.0093 - CB_logloss: inf - val_loss: 0.0709 - val_mse: 0.0105 - val_CB_logloss: inf
# Epoch 55/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0655 - mse: 0.0092 - CB_logloss: inf - val_loss: 0.0710 - val_mse: 0.0105 - val_CB_logloss: inf
# Epoch 56/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0652 - mse: 0.0092 - CB_logloss: inf - val_loss: 0.0707 - val_mse: 0.0104 - val_CB_logloss: inf
# Epoch 57/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0650 - mse: 0.0091 - CB_logloss: inf - val_loss: 0.0715 - val_mse: 0.0106 - val_CB_logloss: inf
# Epoch 58/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0649 - mse: 0.0091 - CB_logloss: inf - val_loss: 0.0704 - val_mse: 0.0104 - val_CB_logloss: inf
# Epoch 59/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0649 - mse: 0.0091 - CB_logloss: inf - val_loss: 0.0725 - val_mse: 0.0108 - val_CB_logloss: inf
# Epoch 60/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0646 - mse: 0.0090 - CB_logloss: inf - val_loss: 0.0708 - val_mse: 0.0104 - val_CB_logloss: inf
# Epoch 61/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0644 - mse: 0.0090 - CB_logloss: inf - val_loss: 0.0709 - val_mse: 0.0105 - val_CB_logloss: inf
# Epoch 62/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0643 - mse: 0.0089 - CB_logloss: inf - val_loss: 0.0713 - val_mse: 0.0105 - val_CB_logloss: inf
# Epoch 63/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0643 - mse: 0.0089 - CB_logloss: inf - val_loss: 0.0703 - val_mse: 0.0103 - val_CB_logloss: inf
# Epoch 64/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0639 - mse: 0.0088 - CB_logloss: inf - val_loss: 0.0707 - val_mse: 0.0104 - val_CB_logloss: inf
# Epoch 65/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0639 - mse: 0.0088 - CB_logloss: inf - val_loss: 0.0709 - val_mse: 0.0104 - val_CB_logloss: inf
# Epoch 66/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0637 - mse: 0.0088 - CB_logloss: inf - val_loss: 0.0698 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 67/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0636 - mse: 0.0087 - CB_logloss: inf - val_loss: 0.0703 - val_mse: 0.0103 - val_CB_logloss: inf
# Epoch 68/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0634 - mse: 0.0087 - CB_logloss: inf - val_loss: 0.0701 - val_mse: 0.0103 - val_CB_logloss: inf
# Epoch 69/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0633 - mse: 0.0087 - CB_logloss: inf - val_loss: 0.0699 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 70/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0632 - mse: 0.0087 - CB_logloss: inf - val_loss: 0.0701 - val_mse: 0.0103 - val_CB_logloss: inf
# Epoch 71/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0630 - mse: 0.0086 - CB_logloss: inf - val_loss: 0.0697 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 72/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0627 - mse: 0.0086 - CB_logloss: inf - val_loss: 0.0701 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 73/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0629 - mse: 0.0086 - CB_logloss: inf - val_loss: 0.0700 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 74/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0625 - mse: 0.0085 - CB_logloss: inf - val_loss: 0.0701 - val_mse: 0.0103 - val_CB_logloss: inf
# Epoch 75/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0625 - mse: 0.0085 - CB_logloss: inf - val_loss: 0.0696 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 76/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0623 - mse: 0.0085 - CB_logloss: inf - val_loss: 0.0692 - val_mse: 0.0101 - val_CB_logloss: inf
# Epoch 77/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0622 - mse: 0.0084 - CB_logloss: inf - val_loss: 0.0697 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 78/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0622 - mse: 0.0084 - CB_logloss: inf - val_loss: 0.0700 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 79/120
# 391/391 [==============================] - 22s 58ms/step - loss: 0.0620 - mse: 0.0084 - CB_logloss: inf - val_loss: 0.0694 - val_mse: 0.0101 - val_CB_logloss: inf
# Epoch 80/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0618 - mse: 0.0083 - CB_logloss: inf - val_loss: 0.0699 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 81/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.0617 - mse: 0.0083 - CB_logloss: inf - val_loss: 0.0692 - val_mse: 0.0101 - val_CB_logloss: inf
# Epoch 82/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0615 - mse: 0.0083 - CB_logloss: inf - val_loss: 0.0700 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 83/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0615 - mse: 0.0083 - CB_logloss: inf - val_loss: 0.0695 - val_mse: 0.0101 - val_CB_logloss: inf
# Epoch 84/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0614 - mse: 0.0082 - CB_logloss: inf - val_loss: 0.0695 - val_mse: 0.0101 - val_CB_logloss: inf
# Epoch 85/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0612 - mse: 0.0082 - CB_logloss: inf - val_loss: 0.0700 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 86/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0612 - mse: 0.0082 - CB_logloss: inf - val_loss: 0.0696 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 87/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0609 - mse: 0.0081 - CB_logloss: inf - val_loss: 0.0699 - val_mse: 0.0102 - val_CB_logloss: inf
# Epoch 88/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0609 - mse: 0.0081 - CB_logloss: inf - val_loss: 0.0694 - val_mse: 0.0101 - val_CB_logloss: inf
# Epoch 89/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0608 - mse: 0.0081 - CB_logloss: inf - val_loss: 0.0701 - val_mse: 0.0101 - val_CB_logloss: inf
# Epoch 90/120
# 391/391 [==============================] - 22s 57ms/step - loss: 0.0607 - mse: 0.0081 - CB_logloss: inf - val_loss: 0.0692 - val_mse: 0.0101 - val_CB_logloss: inf
# Epoch 91/120
# 390/391 [============================>.] - ETA: 0s - loss: 0.0606 - mse: 0.0080 - CB_logloss: infRestoring model weights from the end of the best epoch: 81.
# 391/391 [==============================] - 22s 58ms/step - loss: 0.0606 - mse: 0.0080 - CB_logloss: inf - val_loss: 0.0692 - val_mse: 0.0101 - val_CB_logloss: inf
# Epoch 91: early stopping

# %%
plt.plot(history.history['loss']+history2.history['loss'])
plt.plot(history.history['val_loss']+history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mse']+history2.history['mse'])
plt.plot(history.history['val_mse']+history2.history['val_mse'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_mse', 'val_mse'], loc='upper left')
plt.show()

# %% [markdown]
# # **Plotting some of the original images and the corresponding reconstructions**

# %%
def plot_reconstruction(set, name,seed_val, epochs):     #name should be either 'training' or 'validation'
  np.random.seed(seed_val)

  tg_indices = np.random.randint(0,set.shape[0],size = 16)
  img_sample = tf.convert_to_tensor(np.array(set)[tg_indices])
  z_sample = encoder(img_sample)
  img_recon = decoder(z_sample)

  recon = plt.figure(figsize=(9,4))
  recon.suptitle('Reconstructed images (right) from the ' + name + '-set after ' + str(epochs) + ' epochs: no regularisation in the encoder, decoder, latent_dim =' + str(latent_dim), fontweight= 'bold', y=0.93)

  recon.tight_layout()

  for i in range(36):
    recon.add_subplot(4,9,i+1)
    j = int(np.floor(i/9))
    if (i%9) <4:
      img = set[tg_indices[j*4 + (i%9)]]
      plt.imshow(img)
      plt.axis('off')
    elif (i%9)==4:
      img = np.ones((32,32,3))
      plt.imshow(img)
      plt.axis('off')
    else:
      img = img_recon[j*4 + (i%9) - 5]
      plt.imshow(img)
      plt.axis('off')

# %%
plot_reconstruction(img_train, 'training',123,106)

# %%
plot_reconstruction(img_valid,'validation',123,106)

# %% [markdown]
# We waited for the network (with the same architecture that we optimised with mse loss) to start overtraining and then the results are above. The reconstructed images have equally good colour depth as with mse loss, but they are even more blurry it seems. So at least from these experiments mse or CB loss seem to be better options than L1 loss.
